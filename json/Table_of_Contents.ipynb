# %% [markdown]
# <img align="left" src="media/Assets&ArchHeader.jpeg">

# %% [markdown]
# # Db2 ISO JSON Functions
# Welcome to this Db2 lab that highlights the JSON functions that are found in Db2 11.5. This system demonstrates the new JSON features through the use of Jupyter notebooks. If you are not familiar with the use of Jupyter notebooks or Python, the following notebook will guide you through their usage.

# %% [markdown]
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">An Introduction to Jupyter Notebooks</div>
#         <div style="height: 125px"><p style="font-size: 14px">
#              If you are not familiar with the use of Jupyter notebooks or Python, the following notebook
#              will guide you through their usage.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./An_Introduction_to_Jupyter_Notebooks.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">Db2 Magic Commands</div>
#         <div style="height: 125px"><p style="font-size: 14px">
#              Db2 Magic commands are used in all of the notebooks used in this lab.
#              The following notebook provides a tutorial on basics of using the Db2 magic commands.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Db2_Jupyter_Extensions_Tutorial.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>

# %% [markdown]
# These notebooks on Db2 JSON are very detailed and are intended to be run in sequence. This first notebook is an overview of the JSON functions.

# %% [markdown]
# <!-- Row 1 -->
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Db2 ISO SQL JSON Function Overview
#         </div>
#         <div style="height: 120px"><p style="font-size: 14px">
# <!-- Description -->
# Db2 Version 11.1 Fix pack 4 introduced a subset of the JSON SQL functions defined by ISO that allow you to query, retrieve, and publish JSON data. This notebook provides a quick introduction to these functions if you want to skip the details!
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Db2_11.5_ISO_JSON_Functions.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# An Introduction to JSON
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# Chances are that you have already heard of JSON. JSON is an acronym for "JavaScript Object Notation" and is a way of representing data in a specific format. This notebook gives you a background of what JSON is and how it is used by applications.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 15min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Db2_11.5_JSON_01_An_Introduction_to_JSON.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# JSON Path Expressions
# </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# JSON documents have an inherent structure to them, similar to XML documents. The JSON functions provided with Db2 need a method to navigate through a document to retrieve an object and that is where JSON path expressions are required.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 20min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Db2_11.5_JSON_02_JSON_Path_Expressions.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# <!-- Row 2 -->
# </div>
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# How to Store JSON Documents in Db2</div>
#         <div style="height: 120px"><p style="font-size: 14px">
# <!-- Abstract -->
# The ISO standard does not specify how JSON documents should be stored in relational databases, leaving that decision to the database vendors. This notebook covers the options available to store JSON documents.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Db2_11.5_JSON_04_JSON_Storage.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Inserting and Retrieving JSON Documents
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# Inserting a JSON value into a Db2 table can be done through a variety of methods including LOAD, IMPORT, INGEST, and INSERT statements.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Db2_11.5_JSON_05_Inserting_JSON_Data.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# JSON_EXISTS
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# JSON_EXISTS allows you to check whether or not a valid JSON key exists within a document for the provided search path. You can use the result of this function to determine if the contents of a JSON document is correct.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 20min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Db2_11.5_JSON_06_JSON_EXISTS.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>
# <!-- Row 3 -->
# </div>
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# JSON_VALUE and JSON_QUERY</div>
#         <div style="height: 120px"><p style="font-size: 14px">
# <!-- Abstract -->
# Db2 provides two scalar functions that allow you to extract individual JSON elements from a JSON document in either their native JSON appearance or as an SQL value ready for use in a relational application or SQL statement.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Db2_11.5_JSON_07_JSON_VALUE_and_JSON_QUERY.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# JSON_TABLE
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# The JSON_TABLE function can help you publish the contents of a JSON document in a form that resembles a relational table. This function provides a convenient way of combining multiple JSON_VALUE and JSON_VALUE functions.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 15min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Db2_11.5_JSON_08_JSON_TABLE.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Publishing SQL Data
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# Db2 provides two of the ISO SQL JSON publishing functions: JSON_ARRAY and JSON_OBJECT. The combination of these two functions provide a way of generating complex JSON documents.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 20min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Db2_11.5_JSON_09_Publishing_JSON_Data.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>
# <!-- Row 3 -->
# </div>
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# JSON Performance Optimization</div>
#         <div style="height: 120px"><p style="font-size: 14px">
# <!-- Abstract -->
# Performance considerations will depend on the way that your JSON documents will be accessed by your application. The design decisions you make will have to balance the benefits and cost of each possible solution.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Db2_11.5_JSON_10_Performance_Optimization.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Updating Documents
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# The current ISO SQL JSON standard does not provide for an SQL function to update or delete objects or values within a JSON document. This notebook explores some options that are available in Db2 to update JSON documents.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Db2_11.5_JSON_11_Updating_Documents.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Unnesting Arrays
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# There is currently no single JSON function within Db2 to retrieve all array values. The combination of JSON_EXISTS, JSON_VALUE, JSON_TABLE, and JSON_QUERY can be combined with recursive SQL to extract array objects or individual values.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 20min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Db2_11.5_JSON_12_Unnesting_Arrays.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>
# <!-- Row 3 -->
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Db2 Version 11 JSON Features eBook
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# This book was written to document and demonstrate some of the new JSON functions that are available in Db2 11.5 without you having to search through various forums, blogs, and online manuals.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;
# <!-- Duration -->
# 2hr
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./media/Db2V11-JSON-ebook.pdf">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#FFFFFF; width: 300px; height: 250px;">
#     </td>
# </table>
# </div>

# %% [markdown]
# #### Questions and Comments: George Baklarz [baklarz@ca.ibm.com]
